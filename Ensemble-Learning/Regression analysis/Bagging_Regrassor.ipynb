# %% [markdown]
# ________________________________________________________________________________________________________________________
#
#
# * Yuvraj Sutar
# * yuvrajsutar009@gmail.com
# _ _________________________________________________________________________________________________________________________
# _  _________________________________________________________________________________________________________________________

# %%
# import libraries 
import pandas as pd 
import numpy as np

# %% [markdown]
#  Read data

# %%
df = pd.read_csv("C:\\Users\\Yuvraj\\Desktop\\Data Science\\Data\\USA_Housing.csv")

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 4                             4.23     26354.109472  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
df.drop('Address',axis=1,inplace=True)

# %% [markdown]
#  separate dependant and independant variable in x,y

# %%
x=df.iloc[:,0:5]

# %%
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# 1                             3.09     40173.072174
# 2                             5.13     36882.159400
# 3                             3.26     34310.242831
# 4                             4.23     26354.109472
# ...                            ...              ...
# 4995                          3.46     22837.361035
# 4996                          4.02     25616.115489
# 4997                          2.13     33266.145490
# 4998                          5.44     42625.620156
# 4999                          4.07     46501.283803
#
# [5000 rows x 5 columns]

# %%
y=df.iloc[:,5]

# %% [markdown]
#  split the data in train and test side

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=11)

# %% [markdown]
# Import model

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor

cart = DecisionTreeRegressor()
model = BaggingRegressor(base_estimator=cart, n_estimators=100, random_state=7)

# %% [markdown]
#  Fit the model and predict the output

# %%
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %% [markdown]
# RMSE (Root_mean_squared_error)

# %%
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for mse in range(30):
    mse= mse+1
    knn = DecisionTreeRegressor(criterion = 'mse')
    error =np.sqrt(mean_squared_error(y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , mse , 'is:', error)
# Out:
# RMSE value for k=  1 is: 118865.67761018996
# RMSE value for k=  2 is: 118865.67761018996
# RMSE value for k=  3 is: 118865.67761018996
# RMSE value for k=  4 is: 118865.67761018996
# RMSE value for k=  5 is: 118865.67761018996
# RMSE value for k=  6 is: 118865.67761018996
# RMSE value for k=  7 is: 118865.67761018996
# RMSE value for k=  8 is: 118865.67761018996
# RMSE value for k=  9 is: 118865.67761018996
# RMSE value for k=  10 is: 118865.67761018996
# RMSE value for k=  11 is: 118865.67761018996
# RMSE value for k=  12 is: 118865.67761018996
# RMSE value for k=  13 is: 118865.67761018996
# RMSE value for k=  14 is: 118865.67761018996
# RMSE value for k=  15 is: 118865.67761018996
# RMSE value for k=  16 is: 118865.67761018996
# RMSE value for k=  17 is: 118865.67761018996
# RMSE value for k=  18 is: 118865.67761018996
# RMSE value for k=  19 is: 118865.67761018996
# RMSE value for k=  20 is: 118865.67761018996
# RMSE value for k=  21 is: 118865.67761018996
# RMSE value for k=  22 is: 118865.67761018996
# RMSE value for k=  23 is: 118865.67761018996
# RMSE value for k=  24 is: 118865.67761018996
# RMSE value for k=  25 is: 118865.67761018996
# RMSE value for k=  26 is: 118865.67761018996
# RMSE value for k=  27 is: 118865.67761018996
# RMSE value for k=  28 is: 118865.67761018996
# RMSE value for k=  29 is: 118865.67761018996
# RMSE value for k=  30 is: 118865.67761018996

# %% [markdown]
# * Yuvraj Sutar
# * yuvrajsutar009@gmail.com
